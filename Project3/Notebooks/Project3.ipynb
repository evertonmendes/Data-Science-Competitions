# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Not connected to a GPU

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJECT_PATH="/content/drive/MyDrive/Data_Science_Competitions/Project3/"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
train_df=pd.read_csv(PROJECT_PATH+"Data/train.csv")

# %% [markdown]
# - Question One

# %%
from drive.MyDrive.Data_Science_Competitions.Project3.Utils.Data_analysis.analysis import plot_digits

# %%
plot_digits(train_df)

# %%
from drive.MyDrive.Data_Science_Competitions.Project3.Utils.Data_analysis.analysis import hist_of_digits

# %%
hist_of_digits(train_df)

# %% [markdown]
# - Question Two

# %%
from drive.MyDrive.Data_Science_Competitions.Project3.Utils.Data_analysis.analysis import drop_no_information

# %%
new_train_df, columns_to_keep=drop_no_information(train_df)

# %% [markdown]
# - Question Three

# %%
# !pip install --upgrade scikit-learn

# %%
# !pip install --upgrade scikit-optimize

# %%
'''
 classifiers = [
        'lgbm_clf_n_calls',
        'xgbrf_dart_clf_n_calls',
        'xgbrf_gbtree_clf_n_calls',
        'xgbrf_linear_clf_n_calls',
        'xgb_gbtree_clf_n_calls',
        'xgb_dart_clf_n_calls',
        'xgb_linear_clf_n_calls',
        'gaussianNB_clf_n_calls',
        'Decision_Tree_clf_n_calls',
        'Random_Forest_clf_n_calls',
        'AdaBoost_clf_n_calls',
        'gradientBooster_clf_n_calls',
        'HistGradientBooster_clf_n_calls',
        'knc_clf_n_calls',
        'Knn_clf_n_calls',
        'svc_clf_n_calls',
        'QDA_clf_n_calls',
        'PassiveAggressive_clf_n_calls',
        'sgd_n_calls',
        'ridge_false_n_calls',
        'ridge_positive_n_calls',
        'perceptron_n_calls']


    classifiers = [
        'LGBMClassifier',
        'XGBRFClassifier_dart',
        'XGBRFClassifier_gbtree',
        'XGBRFClassifier_linear',
        'XGBClassifier_gbtree',
        'XGBClassifier_dart',
        'XGBClassifier_linear',
        'GaussianNB',
        'DecisionTreeClassifier',
        'RandomForestClassifier',
        'AdaBoostClassifier',
        'GradientBoostingClassifier',
        'HistGradientBoostingClassifier',
        'KNeighborsClassifier',
        'NearestCentroid',
        'SVC',
        'PassiveAggressiveClassifier',
        'SGDClassifier',
        'RidgeClassifierFalse',
        'RidgeClassifierPositive',
        'Perceptron',
        'QuadraticDiscriminantAnalysis'
        ]
'''
# Out:
# "\n classifiers = [\n        'lgbm_clf_n_calls',\n        'xgbrf_dart_clf_n_calls',\n        'xgbrf_gbtree_clf_n_calls',\n        'xgbrf_linear_clf_n_calls',\n        'xgb_gbtree_clf_n_calls',\n        'xgb_dart_clf_n_calls',\n        'xgb_linear_clf_n_calls',\n        'gaussianNB_clf_n_calls',\n        'Decision_Tree_clf_n_calls',\n        'Random_Forest_clf_n_calls',\n        'AdaBoost_clf_n_calls',\n        'gradientBooster_clf_n_calls',\n        'HistGradientBooster_clf_n_calls',\n        'knc_clf_n_calls',\n        'Knn_clf_n_calls',\n        'svc_clf_n_calls',\n        'QDA_clf_n_calls',\n        'PassiveAggressive_clf_n_calls',\n        'sgd_n_calls',\n        'ridge_false_n_calls',\n        'ridge_positive_n_calls',\n        'perceptron_n_calls']\n\n\n    classifiers = [\n        'LGBMClassifier',\n        'XGBRFClassifier_dart',\n        'XGBRFClassifier_gbtree',\n        'XGBRFClassifier_linear',\n        'XGBClassifier_gbtree',\n        'XGBClassifier_dart',\n        'XGBC
# ...

# %%
from drive.MyDrive.Data_Science_Competitions.Project3.Main_Scikit import Main

# %%
calls= {
    'lgbm_clf_n_calls':15,
    'xgbrf_dart_clf_n_calls':15,
    'xgbrf_gbtree_clf_n_calls':15,
    'xgb_gbtree_clf_n_calls':15,
    'xgb_dart_clf_n_calls':15,
    'gaussianNB_clf_n_calls':20,
    'Decision_Tree_clf_n_calls':15,
    'Random_Forest_clf_n_calls':15,
    'AdaBoost_clf_n_calls':15,
    'gradientBooster_clf_n_calls':15,
    'HistGradientBooster_clf_n_calls':15,
    'knc_clf_n_calls':20,
    'Knn_clf_n_calls':15,
    'svc_clf_n_calls':20,
    'PassiveAggressive_clf_n_calls':20,
    'sgd_n_calls':20,
    'ridge_false_n_calls':20,
    'ridge_positive_n_calls':20,
    'perceptron_n_calls':20,
    'QDA_clf_n_calls':20
}

# %%
Main(calls, trigger_plot=True)
# Out:
# {'lgbm_clf_n_calls': 15, 'xgbrf_dart_clf_n_calls': 15, 'xgbrf_gbtree_clf_n_calls': 15, 'xgb_gbtree_clf_n_calls': 15, 'xgb_dart_clf_n_calls': 15, 'gaussianNB_clf_n_calls': 20, 'Decision_Tree_clf_n_calls': 15, 'Random_Forest_clf_n_calls': 15, 'AdaBoost_clf_n_calls': 15, 'gradientBooster_clf_n_calls': 15, 'HistGradientBooster_clf_n_calls': 15, 'knc_clf_n_calls': 20, 'Knn_clf_n_calls': 15, 'svc_clf_n_calls': 20, 'PassiveAggressive_clf_n_calls': 20, 'sgd_n_calls': 20, 'ridge_false_n_calls': 20, 'ridge_positive_n_calls': 20, 'perceptron_n_calls': 20, 'QDA_clf_n_calls': 20}
# Training Model
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# ...
